# %% [markdown]
# ### Introduction
# This notebook (03_model_training.ipynb) was executed in Google Colab, which provides access to cloud-based GPUs for faster training. Due to this environment, some code snippets are specific to Colab, such as those related to Google Drive integration for loading and saving models, datasets, and results. The main goal of this notebook is to train a Convolutional Neural Network (CNN) for image classification using the CIFAR-10 dataset.

# %% [markdown]
# ### Importing Libraries

# %%
from google.colab import drive
import os

# %% [markdown]
# ### Accessing Google Drive Content

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/My Drive/cnn-cifar10-classifier"
os.chdir(project_path)
print("files:", os.listdir())
# Out:
# files: ['README.md', 'requirements.txt', '.gitignore', 'notebooks', 'data', 'venv', 'src', '.git', 'models', 'results']

# %% [markdown]
# ### Running the Model Training

# %%
# !python src/train.py
# Out:
# 2025-02-26 17:27:54.333475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740590874.351721   14438 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740590874.357327   14438 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Data loaded successfully!
# Training shape: (40000, 32, 32, 3), Labels: (40000, 10)
# Validation shape: (10000, 32, 32, 3), Labels: (10000, 10)
# Test shape: (10000, 32, 32, 3), Labels: (10000, 10)
# ...
